# %% [markdown]
# ### osu!nn #1: Map Dataset Reader
#
# This notebook reads a file "maplist.txt", then reads the .osu files and the relevant music files to convert into some data.
#
# Data that feeds the Deep Neural Network.
#
# Last edit: 2019/4/22

# %% [markdown]
# First of all, we need to install FFmpeg and specify its path here. It is needed to convert the .mp3 files to .wavs which Python can read.
#
# It's also fine to use any other converter, such as LAME: just edit the 24th line of osureader.py (starting with "subprocess.call") for the converter's parameters.
#
# **Then, fill maplist.txt  with the paths of .osu files you want to train with.** Otherwise it cannot find any of the maps because the maps are on my computer. The default model is trained with the Sota dataset including 44 maps of Sota Fujimori music.
#
# After that run the grid below to convert the maps.

# %%
import os, re, time
from osureader import * 

# set the ffmpeg path here!!
# add "r" before the path string

GLOBAL_VARS["ffmpeg_path"] = r"E:\aimapper\ffmpeg.exe";

# in linux, it is installed globally, so use this
# GLOBAL_VARS["ffmpeg_path"] = "ffmpeg";

mapdata_path = "mapdata/";

# check if it works
test_process_path(GLOBAL_VARS["ffmpeg_path"]);

# check if nodejs works
test_process_path("node");

# the divisor parameter
divisor = 4;

# make sure the mapdata folder exists
if not os.path.isdir(mapdata_path):
    os.mkdir(mapdata_path);

with open("maplist.txt") as fp:
    fcont = fp.readlines();

# The following part is something I used to filter maps with difficulty names
results = [];
# exclude_words = ["Easy", "Normal", "Hard", "Taiko", "Salad", "Platter", "Overdose", "Rain", "4K", "5K", "6K", "7K", "8K", "9K",
#                  "Kantan", "Futsuu", "Muzukashii", "Oni", "Field "];
for line in fcont:
#     if re.search("TV", line):
#         apd = True;
#         for kw in exclude_words:
#             if kw.lower() in line.strip().lower():
#                 apd = False;
#                 break;
#         if apd:
#             results.append(line.strip());
    results.append(line);

# Remove the originally existing npzs
for file in os.listdir(mapdata_path):
    if file.endswith(".npz"):
        os.remove(os.path.join(mapdata_path, file));

print("Number of filtered maps: {}".format(len(results)));

for k, mname in enumerate(results):
    try:
        start = time.time()
        read_and_save_osu_file(mname.strip(), filename=os.path.join(mapdata_path, str(k)), divisor=divisor);
        end = time.time()
        print("Map data #" + str(k) + " saved! time = " + str(end - start) + " secs");
    except Exception as e:
        print("Error on #{}, path = {}, error = {}".format(str(k), mname.strip(), e));

# If some map causes bug please tell me!! https://discord.gg/npmSy7K
# Out:
# Number of filtered maps: 184
# Map data #0 saved! time = 3.4319815635681152 secs
# Map data #1 saved! time = 2.0757343769073486 secs
# Map data #2 saved! time = 2.296329975128174 secs
# Map data #3 saved! time = 1.6495962142944336 secs
# Map data #4 saved! time = 2.1562416553497314 secs
# Map data #5 saved! time = 1.5451762676239014 secs
# Map data #6 saved! time = 2.399606466293335 secs
# Map data #7 saved! time = 2.0539581775665283 secs
# Map data #8 saved! time = 1.2822644710540771 secs
# Map data #9 saved! time = 2.022984504699707 secs
# Map data #10 saved! time = 1.8525292873382568 secs
# Map data #11 saved! time = 2.3854434490203857 secs
# Map data #12 saved! time = 2.2940573692321777 secs
# Map data #13 saved! time = 1.5031518936157227 secs
# Map data #14 saved! time = 3.1932625770568848 secs
# Map data #15 saved! time = 1.6984152793884277 secs
# Map data #16 saved! time = 1.38386869430542 secs
# Map data #17 saved! time = 1.4651968479156494 secs
# Map data #18 saved! time = 2.484635353088379 secs
# Map data #19 saved! time = 3.053575038909912 secs
# Map data #20 saved! time = 3.0208821296691895 secs
# Map data #21 saved! time = 3.8042383193969727 secs
# Map data #22 saved! time = 1.4985017776489258 secs
# Map data #23 saved! time = 2.8314664363861084 secs
# Map data #24 saved! time = 2.3527615070343018 secs
# Map data #25 saved! time = 2.464540958404541 secs
# Map data #26 saved! time = 1.3265492916107178 secs
# Map data #27 saved! time = 2.9236714839935303 secs
# Map data #28 saved! time = 2.6402206420898438 secs
# Map data #29 saved! time = 2.2215116024017334 secs
# Map data #30 saved! time = 3.362483501434326 secs
# Map data #31 saved! time = 1.8665728569030762 secs
# Map data #32 saved! time = 2.8804075717926025 secs
# Map data #33 saved! time = 2.749218463897705 secs
# Map data #34 saved! time = 1.640282154083252 secs
# Map data #35 saved! time = 2.156400203704834 secs
# Map data #36 saved! time = 1.377821922302246 secs
# Map data #37 saved! time = 1.2673797607421875 secs
# Map data #38 saved! time = 2.957732915878296 secs
# Map data #39 saved! time = 1.8456215858459473 secs
# Map data #40 saved! time = 2.6734793186187744 secs
# Map data #41 saved! time = 1.2342607975006104 secs
# Map data #42 saved! time = 3.2297112941741943 secs
# Map data #43 saved! time = 2.6843011379241943 secs
# Map data #44 saved! time = 1.2372355461120605 secs
# Map data #45 saved! time = 2.0475926399230957 secs
# Map data #46 saved! time = 3.2531850337982178 secs
# Map data #47 saved! time = 2.816509485244751 secs
# Map data #48 saved! time = 3.1984262466430664 secs
# Map data #49 saved! time = 1.4323465824127197 secs
# Map data #50 saved! time = 1.9739208221435547 secs
# Map data #51 saved! time = 1.7842938899993896 secs
# Map data #52 saved! time = 1.512422800064087 secs
# Map data #53 saved! time = 2.325725793838501 secs
# Map data #54 saved! time = 1.994107961654663 secs
# Map data #55 saved! time = 2.4340295791625977 secs
# Map data #56 saved! time = 3.3338887691497803 secs
# Map data #57 saved! time = 1.5451276302337646 secs
# Map data #58 saved! time = 1.9102704524993896 secs
# Map data #59 saved! time = 2.22421932220459 secs
# Map data #60 saved! time = 2.519252061843872 secs
# Map data #61 saved! time = 1.5238277912139893 secs
# Map data #62 saved! time = 3.7959022521972656 secs
# Map data #63 saved! time = 2.9178574085235596 secs
# Map data #64 saved! time = 1.5427894592285156 secs
# Map data #65 saved! time = 3.0576086044311523 secs
# Map data #66 saved! time = 3.325129270553589 secs
# Map data #67 saved! time = 2.8413584232330322 secs
# Map data #68 saved! time = 1.4872643947601318 secs
# Map data #69 saved! time = 1.8109300136566162 secs
# Map data #70 saved! time = 2.1657016277313232 secs
# Map data #71 saved! time = 1.547851800918579 secs
# Map data #72 saved! time = 2.7047836780548096 secs
# Map data #73 saved! time = 2.1439361572265625 secs
# Map data #74 saved! time = 2.3994333744049072 secs
# Map data #75 saved! time = 2.2022476196289062 secs
# Map data #76 saved! time = 3.3240857124328613 secs
# Map data #77 saved! time = 2.168243885040283 secs
# Map data #78 saved! time = 3.027719259262085 secs
# Map data #79 saved! time = 3.1303184032440186 secs
# Map data #80 saved! time = 3.6285319328308105 secs
# Map data #81 saved! time = 1.424604892730713 secs
# Map data #82 saved! time = 2.363915205001831 secs
# Map data #83 saved! time = 2.7158634662628174 secs
# Map data #84 saved! time = 3.4499623775482178 secs
# Map data #85 saved! time = 1.3546512126922607 secs
# Map data #86 saved! time = 1.3297162055969238 secs
# Map data #87 saved! time = 2.96450138092041 secs
# Map data #88 saved! time = 3.5448501110076904 secs
# Map data #89 saved! time = 2.648324966430664 secs
# Map data #90 saved! time = 1.4413409233093262 secs
# Map data #91 saved! time = 1.9820685386657715 secs
# Map data #92 saved! time = 1.3936245441436768 secs
# Map data #93 saved! time = 3.083765745162964 secs
# Map data #94 saved! time = 3.436763048171997 secs
# Map data #95 saved! time = 2.3032662868499756 secs
# Map data #96 saved! time = 1.8341076374053955 secs
# Map data #97 saved! time = 2.3668129444122314 secs
# Map data #98 saved! time = 0.9418356418609619 secs
# Map data #99 saved! time = 1.4259850978851318 secs
# Map data #100 saved! time = 2.081287384033203 secs
# Map data #101 saved! time = 0.9678394794464111 secs
# Map data #102 saved! time = 1.563917875289917 secs
# Map data #103 saved! time = 2.1221320629119873 secs
# Map data #104 saved! time = 2.6834232807159424 secs
# Map data #105 saved! time = 1.2879397869110107 secs
# Map data #106 saved! time = 3.1250717639923096 secs
# Map data #107 saved! time = 2.401912212371826 secs
# Map data #108 saved! time = 2.513021469116211 secs
# Map data #109 saved! time = 2.3671517372131348 secs
# Map data #110 saved! time = 1.461601972579956 secs
# Map data #111 saved! time = 1.2694716453552246 secs
# Map data #112 saved! time = 1.289553165435791 secs
# Error on #113, path = C:\Users\Lewis\AppData\Local\osu!\Songs\632870 Busdriver - Imaginary Places\Busdriver - Imaginary Places (Moreon) [LKR's de_places].osu, error = too many indices for array
# Map data #114 saved! time = 2.967020034790039 secs
# Map data #115 saved! time = 1.2796423435211182 secs
# Map data #116 saved! time = 1.2736399173736572 secs
# Map data #117 saved! time = 1.3364949226379395 secs
# Map data #118 saved! time = 0.8644924163818359 secs
# Map data #119 saved! time = 2.042694568634033 secs
# Map data #120 saved! time = 2.6498453617095947 secs
# Map data #121 saved! time = 2.205911874771118 secs
# Map data #122 saved! time = 1.86378812789917 secs
# Map data #123 saved! time = 2.477787733078003 secs
# Map data #124 saved! time = 1.9643347263336182 secs
# Map data #125 saved! time = 1.3869388103485107 secs
# Map data #126 saved! time = 1.4768731594085693 secs
# Map data #127 saved! time = 2.677184581756592 secs
# Map data #128 saved! time = 2.5398592948913574 secs
# Map data #129 saved! time = 2.1763527393341064 secs
# Map data #130 saved! time = 3.152617931365967 secs
# Map data #131 saved! time = 1.2520358562469482 secs
# Map data #132 saved! time = 1.5687198638916016 secs
# Map data #133 saved! time = 1.3123714923858643 secs
# Map data #134 saved! time = 2.6865053176879883 secs
# Map data #135 saved! time = 2.851038932800293 secs
# Map data #136 saved! time = 7.24058985710144 secs
# Map data #137 saved! time = 3.240499973297119 secs
# Map data #138 saved! time = 1.4572043418884277 secs
# Map data #139 saved! time = 1.0094916820526123 secs
# Map data #140 saved! time = 1.360534429550171 secs
# Map data #141 saved! time = 2.129014730453491 secs
# Map data #142 saved! time = 1.3879437446594238 secs
# Map data #143 saved! time = 2.593855142593384 secs
# Map data #144 saved! time = 1.5175340175628662 secs
# Map data #145 saved! time = 2.8087375164031982 secs
# Map data #146 saved! time = 1.369678258895874 secs
# Map data #147 saved! time = 2.916417121887207 secs
# Map data #148 saved! time = 1.2789809703826904 secs
# Map data #149 saved! time = 1.9969487190246582 secs
# Map data #150 saved! time = 2.5258562564849854 secs
# Map data #151 saved! time = 1.4372344017028809 secs
# Map data #152 saved! time = 1.927492380142212 secs
# Map data #153 saved! time = 1.8514697551727295 secs
# Map data #154 saved! time = 1.7823164463043213 secs
# Map data #155 saved! time = 1.7015984058380127 secs
# Map data #156 saved! time = 1.4315028190612793 secs
# Map data #157 saved! time = 2.016261577606201 secs
# Map data #158 saved! time = 0.9126746654510498 secs
# Map data #159 saved! time = 4.13373589515686 secs
# Map data #160 saved! time = 2.508406162261963 secs
# Map data #161 saved! time = 3.3686811923980713 secs
# Map data #162 saved! time = 1.170426607131958 secs
# Map data #163 saved! time = 1.1265010833740234 secs
# Map data #164 saved! time = 2.72733998298645 secs
# Map data #165 saved! time = 2.5101542472839355 secs
# Map data #166 saved! time = 3.9560160636901855 secs
# Map data #167 saved! time = 3.8776378631591797 secs
# Map data #168 saved! time = 3.0966358184814453 secs
# Map data #169 saved! time = 2.285102128982544 secs
# Map data #170 saved! time = 2.9232890605926514 secs
# Map data #171 saved! time = 1.369612455368042 secs
# Map data #172 saved! time = 4.104193210601807 secs
# Map data #173 saved! time = 1.9317545890808105 secs
# Map data #174 saved! time = 1.3034672737121582 secs
# Map data #175 saved! time = 3.396117687225342 secs
# Map data #176 saved! time = 2.609631299972534 secs
# Map data #177 saved! time = 2.607945203781128 secs
# Map data #178 saved! time = 1.669712781906128 secs
# Map data #179 saved! time = 2.857088565826416 secs
# Map data #180 saved! time = 2.4265310764312744 secs
# Map data #181 saved! time = 1.5077214241027832 secs
# Map data #182 saved! time = 2.0284461975097656 secs
# Map data #183 saved! time = 2.0108416080474854 secs
